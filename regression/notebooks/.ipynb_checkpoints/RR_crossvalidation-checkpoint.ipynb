# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate
from netCDF4 import Dataset
import utils as utl

# %%
Nh = 96
Nt = 37
sspacing = 3
tspacing = 4

HTLS_sknots = np.arange(0,Nh,sspacing)
HTHS_sknots = np.arange(0,Nh,1)
LTHS_tknots = np.arange(0,Nh,tspacing)
Nl = len(HTLS_sknots)
Ns = len(LTHS_tknots)

Dh = Nh*Nh
Dl = Nl*Nl

N = Nt*Ns

# %%
ncfile1 = Dataset('/data/ISOTROPIC/data/data_downsampled4.nc','r')
x_HR_ref = np.array(ncfile1.variables['velocity_x'][0,0:Nh,0:Nh,0])
ncfile1.close()
x_LR = x_HR_ref[0:-1:sspacing,0:-1:sspacing]
x_interp = utl.interp2(HTLS_sknots, HTLS_sknots, x_LR, HTHS_sknots, HTHS_sknots)

fig = plt.figure(figsize=(13, 5))

ax = plt.subplot(1,3, 1)
cax = plt.imshow(x_HR_ref, interpolation='none',clim=[-3,3],cmap='jet')
ax.set_xticks(())
ax.set_yticks(())
    
ax = plt.subplot(1,3, 2)
cax = plt.imshow(x_LR, interpolation='none',clim=[-3,3],cmap='jet')
ax.set_xticks(())
ax.set_yticks(())

ax = plt.subplot(1,3, 3)
cax = plt.imshow(x_interp, interpolation='none',clim=[-3,3],cmap='jet')
ax.set_xticks(())
ax.set_yticks(())

# fig.colorbar(cax, ticks=[-3, -2, -1, 0, 1, 2, 3])
# Out:
# []

# %%
Xh_tr = np.zeros((N, Dh))
Xl_tr = np.zeros((N, Dl))
ncfile1 = Dataset('/data/ISOTROPIC/data/data_downsampled4.nc','r')
for t in range(Nt):
    count = 0
    for i in LTHS_tknots:
        xh = np.array(ncfile1.variables['velocity_x'][t,0:Nh,0:Nh,i])
        xl = xh[0:-1:sspacing,0:-1:sspacing] # xh[np.meshgrid(HTLS_sknots,HTLS_sknots)]
        Xh_tr[t*Ns + count,:] = np.reshape(xh,(1, Dh))
        Xl_tr[t*Ns + count,:] = np.reshape(xl,(1, Dl))
        count = count + 1
ncfile1.close()

# %%
# normalized: centered, variance 1
mea_l = np.zeros(Dl)
sig_l = np.zeros(Dl)
for k in range(Dl):
    mea_l[k] = np.mean(Xl_tr[:,k])
    sig_l[k] = np.std(Xl_tr[:,k])
    Xl_tr[:,k] = (Xl_tr[:,k]-mea_l[k])/sig_l[k] 
    
mea_h = np.zeros(Dh)
sig_h = np.zeros(Dh)
for k in range(Dh):
    mea_h[k] = np.mean(Xh_tr[:,k])
    sig_h[k] = np.std(Xh_tr[:,k])
    Xh_tr[:,k] = (Xh_tr[:,k]-mea_h[k])/sig_h[k]

# %% [markdown]
# ### Using RidgeCV to get a rough idea of optimal lambda

# %%
from sklearn.linear_model import RidgeCV

n_alphas = 10
alphas = np.linspace(1e-10, 500, n_alphas)

ridge = RidgeCV(alphas = alphas, cv = 6, fit_intercept=False, normalize=False)
ridge.fit(Xl_tr, Xh_tr)
# Out:
# RidgeCV(alphas=array([  1.00000e-10,   5.55556e+01,   1.11111e+02,   1.66667e+02,
#          2.22222e+02,   2.77778e+02,   3.33333e+02,   3.88889e+02,
#          4.44444e+02,   5.00000e+02]),
#     cv=6, fit_intercept=False, gcv_mode=None, normalize=False,
#     scoring=None, store_cv_values=False)

# %%
print 'Optimal set of coefficients:', ridge.coef_
print 'Optimal regularization parameter:', ridge.alpha_
print np.shape(ridge.coef_)
# Out:
# Optimal set of coefficients: [[ 0.63155619  0.0741841  -0.01463561 ..., -0.00248377  0.00600521
#    0.02026639]
#  [ 0.51484966  0.25651381 -0.025592   ...,  0.00424688  0.00486014
#   -0.00547883]
#  [ 0.27818967  0.48911077 -0.0168206  ...,  0.00393079  0.000746
#   -0.01039044]
#  ...,
#  [ 0.07913634  0.00476832 -0.01528806 ..., -0.02092857  0.0665166
#    0.2309682 ]
#  [ 0.2281361  -0.001189   -0.00954213 ..., -0.02546336  0.0083498
#    0.20816361]
#  [ 0.40450636 -0.00521915 -0.01565749 ..., -0.00375429 -0.00843874
#    0.12453829]]
# Optimal regularization parameter: 55.5555555556
# (9216, 1024)

# %%
fig = plt.figure(figsize=(8, 7))
plt.imshow(np.reshape(ridge.coef_[:,135],(96,96)),interpolation='none')

# %% [markdown]
# ### Cross-Validation curve

# %%
from sklearn.linear_model import Ridge
from sklearn.learning_curve import validation_curve

param_range= np.append(0, np.logspace(0, 6, 14))
train_scores, test_scores = validation_curve(Ridge(),Xl_tr, Xh_tr, param_name="alpha", param_range=param_range, 
                                             scoring = "mean_squared_error", cv=10)

# API always tries to maximize a loss function, so MSE is actually in the flipped sign
train_scores_mean = np.mean(-train_scores, axis=1)
train_scores_std = np.std(-train_scores, axis=1)
test_scores_mean = np.mean(-test_scores, axis=1)
test_scores_std = np.std(-test_scores, axis=1)

# %%
plt.figure(figsize=(7, 5))
plt.title("Validation Curve with RR")
plt.xlabel("$\lambda$")
plt.ylabel("Score")
#plt.ylim(0, 1.1)
plt.semilogx(param_range, train_scores_mean, label="Training score", color="r")
plt.fill_between(param_range, train_scores_mean - train_scores_std, 
                 train_scores_mean + train_scores_std, alpha=0.2, color="r")
plt.semilogx(param_range, test_scores_mean, label="Cross-validation score", color="g")
plt.fill_between(param_range, test_scores_mean - test_scores_std, 
                 test_scores_mean + test_scores_std, alpha=0.2, color="g")
plt.legend(loc="best")
plt.show()

# %%
print test_scores
# Out:
# [[-0.44085495 -0.37570773 -0.36049039 -0.3590491  -0.37079693 -0.40391751
#   -0.39944296 -0.36471622 -0.3729479  -0.43505103]
#  [-0.37734322 -0.32140357 -0.31020678 -0.30782103 -0.31807666 -0.34457746
#   -0.34069036 -0.31060832 -0.31941827 -0.36930616]
#  [-0.31683526 -0.26982435 -0.26170958 -0.2592044  -0.2681021  -0.2885641
#   -0.28558876 -0.26059623 -0.26869791 -0.30892036]
#  [-0.25275539 -0.21527157 -0.20970201 -0.20731687 -0.21518926 -0.23024781
#   -0.22758883 -0.20847146 -0.21471304 -0.24582222]
#  [-0.21206016 -0.18021849 -0.17609565 -0.17359306 -0.18095423 -0.19353895
#   -0.19018021 -0.17488216 -0.17959669 -0.20544219]
#  [-0.20623455 -0.17424149 -0.17091029 -0.16762369 -0.17500594 -0.18751633
#   -0.18348392 -0.16888007 -0.17336504 -0.19943493]
#  [-0.23703917 -0.19894024 -0.19639059 -0.19125851 -0.19899999 -0.21361816
#   -0.20865766 -0.19250966 -0.19797675 -0.2305053 ]
#  [-0.30384776 -0.25386626 -0.25268439 -0.24468245 -0.25267451 -0.27153331
#   -0.26451173 -0.2453209  -0.25362559 -0.29916105]
#  [-0.40345209 -0.33651522 -0.33776092 -0.32646086 -0.33444245 -0.35863947
#   -0.34824982 -0.32357905 -0.33896883 -0.40288778]
#  [-0.52919818 -0.44175175 -0.44990897 -0.43376965 -0.44109379 -0.46892472
#   -0.455218   -0.42046367 -0.45046029 -0.53397724]
#  [-0.67005747 -0.56299173 -0.58829185 -0.56554592 -0.56916117 -0.59754378
#   -0.58161917 -0.53238788 -0.58558414 -0.68062322]
#  [-0.81289315 -0.69494855 -0.74129331 -0.7197497  -0.71620826 -0.74384235
#   -0.72080523 -0.66119069 -0.74153424 -0.82846549]
#  [-0.93660436 -0.82098137 -0.87935104 -0.86945688 -0.86252726 -0.88549629
#   -0.84712694 -0.78952758 -0.89264634 -0.95618717]
#  [-1.01753656 -0.90906164 -0.97088047 -0.97120621 -0.96535213 -0.98105304
#   -0.92935471 -0.87945414 -0.99561723 -1.03947979]
#  [-1.0566825  -0.95286795 -1.01528174 -1.0205959  -1.01610147 -1.02697785
#   -0.96847594 -0.923809   -1.04557723 -1.0795685 ]]
